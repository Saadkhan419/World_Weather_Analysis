# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID           City Country                 Date      Lat       Lng  \
# 0        0            Voi      KE  2021-10-12 19:25:13  -3.3945   38.5630
# 1        1           Hilo      US  2021-10-12 19:25:14  19.7297 -155.0900
# 2        2  San Policarpo      PH  2021-10-12 19:25:14  12.1791  125.5072
# 3        3      Kedrovoye      RU  2021-10-12 19:25:14  57.1576   60.5698
# 4        4     Zlate Hory      CZ  2021-10-12 19:25:15  50.2638   17.3960
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     71.55        80         100       11.36
# 1     82.27        93          90        6.91
# 2     80.11        80          99        8.21
# 3     47.64        92         100        5.73
# 4     46.18        88         100        3.02

# %%
#Get the data types.
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
#Configure gmaps to use your google api key.
gmaps.configure(api_key=g_key)

# %%
# Get the max teperature.
max_temp =  city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature.
# Get the latitude and longitude.
locations=city_data_df[["Lat","Lng"]]


#Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

#Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp,0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)

#Add the heatmap layer.
fig.add_layer(heat_layer)

#Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness.
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed.
locations = city_data_df[["Lat", "Lng"]]
wind_speed = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind_speed, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Ask for user input for minimum and maximum temperature.
print("What are your preffered temperatures?")
min_temp = float(input("min_temp: "))
max_temp = float(input("max_temp: "))

# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
# What are your preffered temperatures?
# min_temp: 75
# max_temp: 90
#     City_ID           City Country                 Date      Lat       Lng  \
# 1         1           Hilo      US  2021-10-12 19:25:14  19.7297 -155.0900
# 2         2  San Policarpo      PH  2021-10-12 19:25:14  12.1791  125.5072
# 7         7        Labuhan      ID  2021-10-12 19:25:16  -6.8844  112.2051
# 8         8  San Cristobal      VE  2021-10-12 19:25:16   7.7669  -72.2250
# 17       17  Manuk Mangkaw      PH  2021-10-12 19:25:19   4.8000  119.8500
# 25       25         Turbat      PK  2021-10-12 19:25:21  26.0023   63.0440
# 26       26      Jamestown      US  2021-10-12 19:22:35  42.0970  -79.2353
# 27       27          Kapaa      US  2021-10-12 19:25:22  22.0752 -159.3190
# 34       34           Daru      PG  2021-10-12 19:25:24  -9.0763  143.2092
# 37       37         Atuona      PF  2021-10-12 19:25:25  -9.8000 -139.0333
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      82.27        93          90        6.91
# 2      80.11        80          99        8.21
# 7      78.12        76         100        9.82
# 8      87.98        72         100        7.74
# 17     83.46        80         100       15.48
# 25     79.39        10           0       12.93
# 26     75.02        66          90        7.00
# 27     82.38        81          75        5.01
# 34     78.33        89         100        7.29
# 37     78.08        72          11       18.16

# %%
preferred_cities_df.count()
# Out:
# City_ID       163
# City          163
# Country       162
# Date          163
# Lat           163
# Lng           163
# Max Temp      163
# Humidity      163
# Cloudiness    163
# Wind Speed    163
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp      Lat       Lng Hotel Name
# 1            Hilo      US     82.27  19.7297 -155.0900
# 2   San Policarpo      PH     80.11  12.1791  125.5072
# 7         Labuhan      ID     78.12  -6.8844  112.2051
# 8   San Cristobal      VE     87.98   7.7669  -72.2250
# 17  Manuk Mangkaw      PH     83.46   4.8000  119.8500
# 25         Turbat      PK     79.39  26.0023   63.0440
# 26      Jamestown      US     75.02  42.0970  -79.2353
# 27          Kapaa      US     82.38  22.0752 -159.3190
# 34           Daru      PG     78.33  -9.0763  143.2092
# 37         Atuona      PF     78.08  -9.8000 -139.0333

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key}

# Adding the hotel names
for index,row in hotel_df.iterrows():
    #Get the latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]

    #Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    #Use the search term "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
       
    #Make request and get the json data from the search
    hotels = requests.get(base_url, params=params).json()
    
    print(params)
    #Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
        print("Hotel not found....skipping")
# Out:
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '19.7297,-155.09'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '12.1791,125.5072'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-6.8844,112.2051'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '7.7669,-72.225'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '4.8,119.85'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '26.0023,63.044'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '42.097,-79.2353'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '22.0752,-159.319'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-9.0763,143.2092'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-9.8,-139.0333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-3.8004,102.2655'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-2.6741,141.3028'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '39.1834,-84.5333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-6.2222,-57.7528'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '20.8947,-156.47'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-0.6,73.0833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '33.2833,134.15'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-3.5534,143.6268'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '9.4942,50.8122'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-0.7393,-90.3518'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '5.9485,80.5353'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '42.6001,-73.9662'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-16.4833,-151.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-20.2333,164.0167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '41.3712,-73.414'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '23.8,-100.7333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-3.6954,128.1814'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '41.1415,-73.3579'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '6.4965,2.6036'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '26.326,43.975'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '22.9333,57.5333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-1.3959,120.7524'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '17.0151,54.0924'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-22.0744,-48.7403'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '22.5667,59.5289'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '5.4112,100.3354'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '3.4568,8.5547'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '33.194,-82.5271'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '0.5333,72.9333'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-2.5744,150.7967'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '29.9737,32.5263'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '24.3448,124.1572'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '24.4667,54.3667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '14.6377,102.7914'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-4.0692,-78.9567'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '11.8464,13.1603'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '30.4167,-107.9167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-8.145,159.5921'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-11.7022,43.2551'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '20.6167,-103.2333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-9.4333,159.95'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '3.9366,41.867'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '3.0707,172.7902'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '5.4802,-53.2011'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '16.9833,73.3'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-2.9248,-39.9167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '6.1241,81.1185'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-17.7333,-149.15'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '22.8909,-109.9124'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '4.9533,-77.366'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '31.6315,-8.0083'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '28.3667,129.4833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '4.375,-7.7169'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '4.9333,-52.3333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-13.8833,167.55'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '11.5,42.5'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '5.3505,48.5268'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '41.5931,-81.5268'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '14.2,24.6667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-17.9167,15.95'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '22.2855,114.1577'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-31.6333,-60.7'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '5.8933,95.3214'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '14.4012,33.5199'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-9.2,25.85'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '11.2408,-74.199'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-3.7481,-73.2472'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '27.2167,77.4833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-2.9167,104.7458'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '12.35,32.1833'}
# Hotel not found....skipping
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '31.4638,-100.437'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-3.9014,-38.3911'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-26.6167,-54.1333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '6.2333,1.6'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-23.2667,-55.5333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '16.8634,-99.8901'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '-19.5933,-46.9406'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '31.61,34.7642'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyCo3rMycmu0I-WcfRyyveyucV9_pRXAHI8', 'location': '