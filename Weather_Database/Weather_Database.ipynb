# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | ambilobe
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | bara
# Processing Record 5 of Set 1 | christchurch
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | ostrovnoy
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | shelburne
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | heishan
# Processing Record 17 of Set 1 | havre-saint-pierre
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | saint-pierre
# Processing Record 20 of Set 1 | chahal
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | kedougou
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | souillac
# Processing Record 27 of Set 1 | belmonte
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | ternate
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | polson
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | albanel
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | warwick
# Processing Record 37 of Set 1 | sangar
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | emerald
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | talaya
# Processing Record 42 of Set 1 | catamarca
# Processing Record 43 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 1 | komsomolskiy
# Processing Record 45 of Set 1 | nea alikarnassos
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | san quintin
# Processing Record 49 of Set 1 | matamoros
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | suao
# City not found. Skipping...
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | holstebro
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | kilindoni
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | sur
# Processing Record 8 of Set 2 | coquimbo
# Processing Record 9 of Set 2 | bonavista
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | ruhengeri
# Processing Record 12 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 2 | toora-khem
# Processing Record 14 of Set 2 | baleshwar
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | aksu
# Processing Record 17 of Set 2 | kenda
# Processing Record 18 of Set 2 | trabzon
# Processing Record 19 of Set 2 | quatre cocos
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | ahuimanu
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | concordia
# Processing Record 26 of Set 2 | sampit
# Processing Record 27 of Set 2 | spoleto
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | kjollefjord
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 2 | atar
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | santa branca
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | yanam
# Processing Record 42 of Set 2 | verkhnyaya toyma
# Processing Record 43 of Set 2 | prainha
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | novikovo
# Processing Record 47 of Set 2 | galle
# Processing Record 48 of Set 2 | libertador general san martin
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | dubrovka
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | zinder
# Processing Record 4 of Set 3 | knyaginino
# Processing Record 5 of Set 3 | tanete
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | fortuna
# Processing Record 12 of Set 3 | sola
# Processing Record 13 of Set 3 | yeppoon
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | kirakira
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | albesti
# Processing Record 19 of Set 3 | linxi
# Processing Record 20 of Set 3 | jutai
# Processing Record 21 of Set 3 | mezen
# Processing Record 22 of Set 3 | tabuk
# Processing Record 23 of Set 3 | tiarei
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | pitimbu
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | lagunas
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | bengkulu
# Processing Record 32 of Set 3 | abu samrah
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | puerto escondido
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | kasane
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | opuwo
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | guapore
# Processing Record 43 of Set 3 | kaihua
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 3 | labuhan
# Processing Record 47 of Set 3 | gisborne
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | maceio
# Processing Record 50 of Set 3 | baykit
# Processing Record 1 of Set 4 | bhandaria
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | hirado
# Processing Record 4 of Set 4 | araouane
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | puerto cabezas
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | tautira
# Processing Record 9 of Set 4 | am timan
# Processing Record 10 of Set 4 | cayenne
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | mayor pablo lagerenza
# Processing Record 14 of Set 4 | balykshi
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | simplicio mendes
# Processing Record 17 of Set 4 | san ramon de la nueva oran
# Processing Record 18 of Set 4 | ati
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | mahibadhoo
# Processing Record 22 of Set 4 | port keats
# Processing Record 23 of Set 4 | te anau
# Processing Record 24 of Set 4 | komatipoort
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | ishimbay
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | alta floresta
# Processing Record 29 of Set 4 | plainfield
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | lasa
# Processing Record 33 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 4 | tezu
# Processing Record 35 of Set 4 | oranjemund
# Processing Record 36 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 4 | vaini
# Processing Record 38 of Set 4 | kigoma
# Processing Record 39 of Set 4 | carauari
# Processing Record 40 of Set 4 | uchiza
# Processing Record 41 of Set 4 | stokmarknes
# Processing Record 42 of Set 4 | hithadhoo
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | dubbo
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | usolye
# Processing Record 47 of Set 4 | walker
# Processing Record 48 of Set 4 | juegang
# Processing Record 49 of Set 4 | hualmay
# Processing Record 50 of Set 4 | kosai
# Processing Record 1 of Set 5 | marsabit
# Processing Record 2 of Set 5 | houston
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | tasiilaq
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 5 | zyryanovsk
# Processing Record 8 of Set 5 | qaanaaq
# Processing Record 9 of Set 5 | manokwari
# Processing Record 10 of Set 5 | solnechnyy
# Processing Record 11 of Set 5 | conde
# Processing Record 12 of Set 5 | alihe
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | yar-sale
# Processing Record 15 of Set 5 | tuktoyaktuk
# Processing Record 16 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 5 | faya
# Processing Record 18 of Set 5 | tura
# Processing Record 19 of Set 5 | nacala
# Processing Record 20 of Set 5 | guangyuan
# Processing Record 21 of Set 5 | mana
# Processing Record 22 of Set 5 | talnakh
# Processing Record 23 of Set 5 | beroroha
# Processing Record 24 of Set 5 | maiduguri
# Processing Record 25 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 26 of Set 5 | leshan
# Processing Record 27 of Set 5 | biggar
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | pitea
# Processing Record 30 of Set 5 | socorro
# Processing Record 31 of Set 5 | vangaindrano
# Processing Record 32 of Set 5 | mazamari
# Processing Record 33 of Set 5 | whitehills
# Processing Record 34 of Set 5 | chokurdakh
# Processing Record 35 of Set 5 | leninskoye
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | grindavik
# Processing Record 38 of Set 5 | batangafo
# Processing Record 39 of Set 5 | nara
# Processing Record 40 of Set 5 | portland
# Processing Record 41 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 5 | mae hong son
# Processing Record 43 of Set 5 | yulara
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | tessalit
# Processing Record 46 of Set 5 | ippy
# Processing Record 47 of Set 5 | salinopolis
# Processing Record 48 of Set 5 | basco
# Processing Record 49 of Set 5 | makakilo city
# Processing Record 50 of Set 5 | myaundzha
# Processing Record 1 of Set 6 | pasinler
# Processing Record 2 of Set 6 | the valley
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | kolondieba
# Processing Record 6 of Set 6 | urengoy
# Processing Record 7 of Set 6 | lamar
# Processing Record 8 of Set 6 | axim
# Processing Record 9 of Set 6 | nassau
# Processing Record 10 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | bilibino
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | lata
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | dunedin
# Processing Record 19 of Set 6 | mizdah
# Processing Record 20 of Set 6 | studenicani
# City not found. Skipping...
# Processing Record 21 of Set 6 | jishou
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | deputatskiy
# Processing Record 24 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 6 | ambon
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | iracoubo
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | miyako
# Processing Record 30 of Set 6 | olafsvik
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | itarema
# Processing Record 34 of Set 6 | locri
# Processing Record 35 of Set 6 | rach gia
# Processing Record 36 of Set 6 | gondanglegi
# Processing Record 37 of Set 6 | deep river
# Processing Record 38 of Set 6 | ryotsu
# Processing Record 39 of Set 6 | honiara
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | bitung
# Processing Record 42 of Set 6 | pangnirtung
# Processing Record 43 of Set 6 | guane
# Processing Record 44 of Set 6 | pozo colorado
# Processing Record 45 of Set 6 | saint-augustin
# Processing Record 46 of Set 6 | port hedland
# Processing Record 47 of Set 6 | kpandu
# Processing Record 48 of Set 6 | sept-iles
# Processing Record 49 of Set 6 | clyde river
# Processing Record 50 of Set 6 | kill
# Processing Record 1 of Set 7 | vao
# Processing Record 2 of Set 7 | marawi
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | plastun
# Processing Record 5 of Set 7 | moyale
# Processing Record 6 of Set 7 | college
# Processing Record 7 of Set 7 | lipin bor
# Processing Record 8 of Set 7 | vila
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | melito di porto salvo
# Processing Record 11 of Set 7 | stornoway
# Processing Record 12 of Set 7 | jibuti
# Processing Record 13 of Set 7 | jinchang
# Processing Record 14 of Set 7 | selfoss
# Processing Record 15 of Set 7 | vares
# Processing Record 16 of Set 7 | huanren
# Processing Record 17 of Set 7 | tanjong malim
# City not found. Skipping...
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | cherskiy
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | old town
# Processing Record 22 of Set 7 | thompson
# Processing Record 23 of Set 7 | zhucheng
# Processing Record 24 of Set 7 | teya
# Processing Record 25 of Set 7 | tarumovka
# Processing Record 26 of Set 7 | geraldton
# Processing Record 27 of Set 7 | barcelos
# Processing Record 28 of Set 7 | la ligua
# Processing Record 29 of Set 7 | karratha
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | hamilton
# Processing Record 32 of Set 7 | leiyang
# Processing Record 33 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 7 | dabhol
# Processing Record 35 of Set 7 | ucluelet
# Processing Record 36 of Set 7 | raudeberg
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | iskateley
# Processing Record 39 of Set 7 | thinadhoo
# Processing Record 40 of Set 7 | moree
# Processing Record 41 of Set 7 | necochea
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | ninotsminda
# Processing Record 44 of Set 7 | gejiu
# Processing Record 45 of Set 7 | ossora
# Processing Record 46 of Set 7 | paita
# Processing Record 47 of Set 7 | san jose
# Processing Record 48 of Set 7 | kodiak
# Processing Record 49 of Set 7 | quballat
# Processing Record 50 of Set 7 | ontario
# Processing Record 1 of Set 8 | hofn
# Processing Record 2 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 3 of Set 8 | sarakhs
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | lanigan
# Processing Record 6 of Set 8 | verkhnevilyuysk
# Processing Record 7 of Set 8 | eyl
# Processing Record 8 of Set 8 | acari
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | trairi
# Processing Record 11 of Set 8 | hami
# Processing Record 12 of Set 8 | magesti
# Processing Record 13 of Set 8 | codajas
# Processing Record 14 of Set 8 | vasvar
# Processing Record 15 of Set 8 | fort nelson
# Processing Record 16 of Set 8 | cidreira
# Processing Record 17 of Set 8 | westport
# Processing Record 18 of Set 8 | zomin
# Processing Record 19 of Set 8 | bar-le-duc
# Processing Record 20 of Set 8 | wukari
# Processing Record 21 of Set 8 | campbell river
# Processing Record 22 of Set 8 | fort-shevchenko
# Processing Record 23 of Set 8 | itacoatiara
# Processing Record 24 of Set 8 | roebourne
# Processing Record 25 of Set 8 | mandalgovi
# Processing Record 26 of Set 8 | chamba
# Processing Record 27 of Set 8 | aykhal
# Processing Record 28 of Set 8 | lebu
# Processing Record 29 of Set 8 | angoche
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | kungurtug
# Processing Record 32 of Set 8 | gaoua
# Processing Record 33 of Set 8 | dwarka
# Processing Record 34 of Set 8 | dali
# Processing Record 35 of Set 8 | cabo san lucas
# Processing Record 36 of Set 8 | great yarmouth
# Processing Record 37 of Set 8 | klaksvik
# Processing Record 38 of Set 8 | pontianak
# Processing Record 39 of Set 8 | synya
# Processing Record 40 of Set 8 | south venice
# Processing Record 41 of Set 8 | makhu
# Processing Record 42 of Set 8 | bairiki
# Processing Record 43 of Set 8 | ha
# City not found. Skipping...
# Processing Record 44 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 8 | gasa
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | soyo
# Processing Record 48 of Set 8 | oliveira dos brejinhos
# Processing Record 49 of Set 8 | taywarah
# Processing Record 50 of Set 8 | broome
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | huaiyuan
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | kieta
# Processing Record 5 of Set 9 | karnal
# Processing Record 6 of Set 9 | orlik
# Processing Record 7 of Set 9 | kucevo
# Processing Record 8 of Set 9 | loukhi
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | terrace
# Processing Record 11 of Set 9 | weihe
# Processing Record 12 of Set 9 | mitu
# Processing Record 13 of Set 9 | caucaia
# Processing Record 14 of Set 9 | menongue
# Processing Record 15 of Set 9 | letterkenny
# Processing Record 16 of Set 9 | chalakudi
# Processing Record 17 of Set 9 | seoul
# Processing Record 18 of Set 9 | yerbogachen
# Processing Record 19 of Set 9 | pocri
# Processing Record 20 of Set 9 | kaura namoda
# Processing Record 21 of Set 9 | khandbari
# Processing Record 22 of Set 9 | vanimo
# Processing Record 23 of Set 9 | methoni
# Processing Record 24 of Set 9 | paranaiba
# Processing Record 25 of Set 9 | serdobsk
# Processing Record 26 of Set 9 | candido de abreu
# Processing Record 27 of Set 9 | nizhniy kuranakh
# Processing Record 28 of Set 9 | henties bay
# Processing Record 29 of Set 9 | danville
# Processing Record 30 of Set 9 | mantua
# Processing Record 31 of Set 9 | wanning
# Processing Record 32 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 33 of Set 9 | mnogovershinnyy
# Processing Record 34 of Set 9 | hutchinson
# Processing Record 35 of Set 9 | chernyshevskiy
# Processing Record 36 of Set 9 | mandera
# Processing Record 37 of Set 9 | tahe
# Processing Record 38 of Set 9 | san andres
# Processing Record 39 of Set 9 | duz
# City not found. Skipping...
# Processing Record 40 of Set 9 | innisfail
# Processing Record 41 of Set 9 | iwaki
# Processing Record 42 of Set 9 | ustrzyki dolne
# Processing Record 43 of Set 9 | tutla
# City not found. Skipping...
# Processing Record 44 of Set 9 | ugoofaaru
# Processing Record 45 of Set 9 | bathurst
# Processing Record 46 of Set 9 | saldanha
# Processing Record 47 of Set 9 | zomba
# Processing Record 48 of Set 9 | banamba
# Processing Record 49 of Set 9 | jiuquan
# Processing Record 50 of Set 9 | kenmare
# Processing Record 1 of Set 10 | verkhoturye
# Processing Record 2 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 10 | padang
# Processing Record 4 of Set 10 | dhidhdhoo
# Processing Record 5 of Set 10 | massakory
# Processing Record 6 of Set 10 | gallup
# Processing Record 7 of Set 10 | akyab
# Processing Record 8 of Set 10 | kysyl-syr
# Processing Record 9 of Set 10 | yongan
# Processing Record 10 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 10 | torbay
# Processing Record 12 of Set 10 | okha
# Processing Record 13 of Set 10 | aguadilla
# Processing Record 14 of Set 10 | rovinj
# Processing Record 15 of Set 10 | grand gaube
# Processing Record 16 of Set 10 | goderich
# Processing Record 17 of Set 10 | birao
# Processing Record 18 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | valdivia
# Processing Record 20 of Set 10 | swan river
# Processing Record 21 of Set 10 | verkhnyaya inta
# Processing Record 22 of Set 10 | teguldet
# Processing Record 23 of Set 10 | foz do iguacu
# Processing Record 24 of Set 10 | gizo
# Processing Record 25 of Set 10 | kenai
# Processing Record 26 of Set 10 | dujuma
# City not found. Skipping...
# Processing Record 27 of Set 10 | cartersville
# Processing Record 28 of Set 10 | pyaozerskiy
# Processing Record 29 of Set 10 | san policarpo
# Processing Record 30 of Set 10 | porto novo
# Processing Record 31 of Set 10 | almeria
# Processing Record 32 of Set 10 | intipuca
# Processing Record 33 of Set 10 | amberley
# Processing Record 34 of Set 10 | luanda
# Processing Record 35 of Set 10 | petushki
# Processing Record 36 of Set 10 | porto nacional
# Processing Record 37 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 10 | seelze
# Processing Record 39 of Set 10 | anloga
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | izumo
# Processing Record 44 of Set 10 | murray bridge
# Processing Record 45 of Set 10 | cockburn town
# Processing Record 46 of Set 10 | goure
# Processing Record 47 of Set 10 | suhbaatar
# Processing Record 48 of Set 10 | kayerkan
# Processing Record 49 of Set 10 | yuzhno-sukhokumsk
# Processing Record 50 of Set 10 | kargopol
# Processing Record 1 of Set 11 | suba
# Processing Record 2 of Set 11 | bohicon
# Processing Record 3 of Set 11 | ixtapa
# Processing Record 4 of Set 11 | kostomuksha
# Processing Record 5 of Set 11 | mangrol
# Processing Record 6 of Set 11 | qaqortoq
# Processing Record 7 of Set 11 | antalaha
# Processing Record 8 of Set 11 | macon
# Processing Record 9 of Set 11 | aleksandrovka
# Processing Record 10 of Set 11 | moron
# Processing Record 11 of Set 11 | manati
# Processing Record 12 of Set 11 | camacha
# Processing Record 13 of Set 11 | xanxere
# Processing Record 14 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 11 | southbridge
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | sakakah
# Processing Record 18 of Set 11 | gawler
# Processing Record 19 of Set 11 | shakawe
# Processing Record 20 of Set 11 | sao joao da barra
# Processing Record 21 of Set 11 | la romana
# Processing Record 22 of Set 11 | cairns
# Processing Record 23 of Set 11 | turukhansk
# Processing Record 24 of Set 11 | lemesos
# City not found. Skipping...
# Processing Record 25 of Set 11 | tooele
# Processing Record 26 of Set 11 | buala
# Processing Record 27 of Set 11 | beian
# Processing Record 28 of Set 11 | kita
# Processing Record 29 of Set 11 | aswan
# Processing Record 30 of Set 11 | biak
# Processing Record 31 of Set 11 | kharian
# Processing Record 32 of Set 11 | paredon
# Processing Record 33 of Set 11 | mecca
# Processing Record 34 of Set 11 | tazmalt
# Processing Record 35 of Set 11 | san julian
# Processing Record 36 of Set 11 | japura
# Processing Record 37 of Set 11 | eidfjord
# Processing Record 38 of Set 11 | pervomayskiy
# Processing Record 39 of Set 11 | phetchaburi
# Processing Record 40 of Set 11 | noumea
# Processing Record 41 of Set 11 | dergachi
# Processing Record 42 of Set 11 | high rock
# Processing Record 43 of Set 11 | onega
# Processing Record 44 of Set 11 | hue
# Processing Record 45 of Set 11 | diamantino
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | guaymas
# Processing Record 48 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 11 | diffa
# Processing Record 50 of Set 11 | praia
# Processing Record 1 of Set 12 | fortuna foothills
# Processing Record 2 of Set 12 | konongo
# Processing Record 3 of Set 12 | malanje
# Processing Record 4 of Set 12 | buraydah
# Processing Record 5 of Set 12 | sheridan
# Processing Record 6 of Set 12 | gracac
# Processing Record 7 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 12 | nouadhibou
# Processing Record 9 of Set 12 | oistins
# Processing Record 10 of Set 12 | nebug
# Processing Record 11 of Set 12 | sao francisco de assis
# Processing Record 12 of Set 12 | nhulunbuy
# Processing Record 13 of Set 12 | russell
# Processing Record 14 of Set 12 | pirenopolis
# Processing Record 15 of Set 12 | rock sound
# Processing Record 16 of Set 12 | mossendjo
# Processing Record 17 of Set 12 | urumqi
# Processing Record 18 of Set 12 | san antonio sacatepequez
# Processing Record 19 of Set 12 | codrington
# Processing Record 20 of Set 12 | arlit
# Processing Record 21 of Set 12 | isla mujeres
# Processing Record 22 of Set 12 | gonc
# Processing Record 23 of Set 12 | phuket
# Processing Record 24 of Set 12 | srednekolymsk
# Processing Record 25 of Set 12 | manzhouli
# Processing Record 26 of Set 12 | srivardhan
# Processing Record 27 of Set 12 | pareora
# Processing Record 28 of Set 12 | waingapu
# Processing Record 29 of Set 12 | gravdal
# Processing Record 30 of Set 12 | esperance
# Processing Record 31 of Set 12 | erken-shakhar
# City not found. Skipping...
# Processing Record 32 of Set 12 | taiping
# Processing Record 33 of Set 12 | pierre
# Processing Record 34 of Set 12 | rocha
# Processing Record 35 of Set 12 | snezhnogorsk
# Processing Record 36 of Set 12 | rolla
# Processing Record 37 of Set 12 | palu
# Processing Record 38 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 12 | krasnyy oktyabr
# Processing Record 40 of Set 12 | umm lajj
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | mikkeli
# Processing Record 43 of Set 12 | gat
# Processing Record 44 of Set 12 | carutapera
# Processing Record 45 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 46 of Set 12 | myatlevo
# Processing Record 47 of Set 12 | arona
# Processing Record 48 of Set 12 | denpasar
# Processing Record 49 of Set 12 | bacolod
# Processing Record 50 of Set 12 | jalu
# Processing Record 1 of Set 13 | valdosta
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | lesnoy
# Processing Record 4 of Set 13 | cururupu
# Processing Record 5 of Set 13 | svolvaer
# Processing Record 6 of Set 13 | brae
# Processing Record 7 of Set 13 | kruisfontein
# Processing Record 8 of Set 13 | mwinilunga
# Processing Record 9 of Set 13 | flinders
# Processing Record 10 of Set 13 | kozhva
# Processing Record 11 of Set 13 | kirovsk
# Processing Record 12 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 13 | tiznit
# Processing Record 14 of Set 13 | kapuskasing
# Processing Record 15 of Set 13 | kaduqli
# Processing Record 16 of Set 13 | husavik
# Processing Record 17 of Set 13 | qax
# Processing Record 18 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 13 | verkhnetulomskiy
# Processing Record 20 of Set 13 | dosso
# Processing Record 21 of Set 13 | yzeure
# Processing Record 22 of Set 13 | kalabo
# Processing Record 23 of Set 13 | york
# Processing Record 24 of Set 13 | rameshki
# Processing Record 25 of Set 13 | vilcun
# Processing Record 26 of Set 13 | kariba
# Processing Record 27 of Set 13 | coatzintla
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Coihaique      CL  2021-10-12 21:51:27 -45.5752  -72.0662     57.81
# 1      Ambilobe      MG  2021-10-12 21:41:48 -13.2000   49.0500     75.18
# 2       Ushuaia      AR  2021-10-12 21:51:27 -54.8000  -68.3000     55.06
# 3          Bara      NG  2021-10-12 21:41:49  10.3744   10.7288     78.78
# 4  Christchurch      NZ  2021-10-12 21:40:47 -43.5333  172.6333     45.00
# 5     Cape Town      ZA  2021-10-12 21:47:00 -33.9258   18.4232     64.09
# 6  Punta Arenas      CL  2021-10-12 21:51:28 -53.1500  -70.9167     57.31
# 7     Ostrovnoy      RU  2021-10-12 21:51:28  68.0531   39.5131     43.74
# 8     Saskylakh      RU  2021-10-12 21:51:29  71.9167  114.0833      9.23
# 9       Rikitea      PF  2021-10-12 21:51:29 -23.1203 -134.9692     74.25
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        50          40        6.91    scattered clouds
# 1        77         100        1.45     overcast clouds
# 2        38          75       18.41       broken clouds
# 3        43          72        3.83       broken clouds
# 4        89          75       11.01       moderate rain
# 5        81          20        1.99          few clouds
# 6        35          75       19.57       broken clouds
# 7        86          97       19.60     overcast clouds
# 8        97          99        4.63     overcast clouds
# 9        74          66        9.80       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
